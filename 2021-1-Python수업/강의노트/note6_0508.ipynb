# %% [markdown]
# # 6. Class

# %% [markdown]
# ### (1) 무야호

# %% [markdown]
# https://youtu.be/abPCcWj5sew

# %% [markdown]
# 유돈노: (회관에 들어서며) 안녕하세요~ 안녕하세요~ 안녕하세요~
#
# 재석: 다름이 아니고 저희가 그, 무한도전 혹시 보신 적이 있으십니까?
#
# 권오성 할아버지: 아니, 잘 몰라요..
#
# 재석: 아...
#
# 최규재 할아버지: 네, 그쵸. 저희가 많이 보죠.
#
# 재석: (아! 아!) 아, 선생님 보셨습니까? (WOW)
#
# 최규재 할아버지: 예, 예.
#
# 홍철: 혹시 액션이 어떻게 되는지 아세요? 무한~
#
# 최규재 할아버지: 무야호~ (??) 뭐...
#
# 유돈노: (웃음) 무야...
#
# 형돈: 무야호... 무야호... 그만큼 신나시는 거지~
#
# 최규재 할아버지: 예, 예. (끄덕끄덕)

# %% [markdown]
# #### 웃음포인트

# %% [markdown]
# - (1) 무야호: ??? 정체불명의 말.. + 좀 당당하게 외침? + 신남?
# - (2) 정형돈: 그만큼 신나시는 거지~
# - ...

# %% [markdown]
# #### 유행

# %% [markdown]
# https://youtu.be/CeWQPhf6iEY

# %% [markdown]
# #### 따라하자!

# %% [markdown]
# [사례1]

# %% [markdown]
# ![image.png](attachment:a496d2d8-256f-4b33-bbcb-6ee2063381d7.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:743e36d2-0b5a-41f6-9e29-fdfaec56a678.png)

# %% [markdown]
# [사례2]

# %% [markdown]
# ![image.png](attachment:01093bb0-c62d-4b9b-87ca-20aa419ccdfa.png)

# %% [markdown]
# [사례3]

# %% [markdown]
# ![image.png](attachment:ed08ac1b-2f6e-48af-9c91-f673533f6b88.png)

# %% [markdown]
# [사례4]

# %% [markdown]
# ![image.png](attachment:dd6ea7e3-b34f-4dc9-94f0-7150909e8367.png)

# %% [markdown]
# [사례5]

# %% [markdown]
# https://youtu.be/Ist8YA6okaw

# %% [markdown]
# [사례6]

# %% [markdown]
# https://youtu.be/hluEw50uVIw

# %% [markdown]
# ***네이버 오픈사전 등재***

# %% [markdown]
# ![image.png](attachment:c9aaac14-a2ed-45cd-8b72-6780c96fd6f2.png)

# %% [markdown]
# ---

# %% [markdown]
# ### (2) 밈, 인터넷 밈
# #### 밈
# - 이기적 유전자에서 제시한 개념
# - 밈(Meme)은 한 사람이나 집단에게서 다른 지성으로 생각 혹은 믿음이 전달될 때 전달되는 모방 가능한 사회적 단위를 총칭
#     - 유전자의 속성: 자기복제 + 번식 + 변화
#     - 종교, 사상, 이념등에 확대
#
# #### 인터넷 밈
# - 밈의 한 형태
# - 인터넷을 통해 사람들에게 전파되는 어떤 생각, 행동, 스타일 등..

# %% [markdown]
# ---

# %% [markdown]
# ### (3) 클래스

# %% [markdown]
# 클래스란 무엇인가?

# %% [markdown]
# - 많은 교재에서 정의를 회피함
# - 비유적 설명 , 다른 대상을 가져와서 설명
#     - 클래스는 과자틀과 비슷하다. 클래스란 똑같은 무엇인가를 계속 만들어 낼 수도 있는 설계도면이고 객체란 클래스로 만든 피조물을 뜻한다. (점프투파이썬)
#     - In object-oriented programming, a class is an extensible program-code-template for creating objects, providing initial values for state (member variables) and implementations of behavior (member functions or methods).`

# %% [markdown]
# - 직접적 설명
#     - 복제를 위한 확장가능한 프로그램 코드의 유닛

# %% [markdown]
# ---

# %% [markdown]
# 밈의 예제로 돌아가보자.

# %% [markdown]
# (1) 무야호 원본 시청

# %% [markdown]
# (2) 복사하고 싶은 속성을 추림

# %% [markdown]
# (3) 복제가능한 어떤 밈(틀)을 만듬
#  - 틀1: 무야호~~~ -> 그만큼 ~하셨다는거지?
#  - 틀2: 무야호 + 영상샘플링 + 음악샘플링

# %% [markdown]
# (4) 밈으로부터 짤을 만든다.

# %% [markdown]
# ---

# %% [markdown]
# 좀더 정리하여 말하면,
#
# (1) 개념의 인지
#
# (2) 복사하고 싶은 속성을 추림
#
# (3) 복사가능한 어떤 틀을 만듬 (=클래스를 정의)
#
# (4) 틀에서 인스턴스를 만든다 (=클래스에서 인스턴스를 만든다)

# %% [markdown]
# ---

# %% [markdown]
# ### [예제1]

# %% [markdown]
# 농심에서 나온 무파마를 먹고, 너무 맛있어서 갑자기 밈으로 놀고 싶어졌다.

# %% [markdown]
# **[예비학습]** 그림 불러오는 함수

# %%
from PIL import Image
Image.open('mooyaho1.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x960 at 0x2CDBF035580>

# %% [markdown]
# 너무 크다..

# %%
Image.open('mooyaho1.jpg').resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF0126D0>

# %% [markdown]
# 에비학습 끝

# %% [markdown]
# `목표:` (1) "농심 무파마"를 출력하고 (2) 무야호 그림을 보여줌 (3) "그만큼 맛있으시단거지" 로 마무리

# %% [markdown]
# #### ***첫 시도: 단순무식***

# %%
title="농심 무파마"
img=Image.open('mooyaho1.jpg').resize((200,200))
don="그만큼 맛있으시단거지"

# %%
print(title)
display(img)
print(don)
# Out:
# 농심 무파마
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF012F70>
# 그만큼 맛있으시단거지

# %% [markdown]
# 짤을 변경하고 싶다면, 아래와 같이 수행하자.

# %%
title="속 시원한 농심 무야호"
print(title)
display(img)
print(don)
# Out:
# 속 시원한 농심 무야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF012F70>
# 그만큼 맛있으시단거지

# %% [markdown]
# `첫 시도의 아쉬움`
# - 드립을 바꾼 여러개의 짤을 관리하기 힘들다.
# - 불필요한 반복도 많다. print, display, print <-- 짤을 만들때마다 반복
# - 코드가 지저분하다. (디버깅이 힘들다)

# %% [markdown]
# #### ***두번째 시도: 모듈***

# %%
import mooyaho

# %%
mooyaho.memeshow(mooyaho.title, mooyaho.img,mooyaho.don)
# Out:
# 속시원한 농심 무야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF000820>
# 그만큼 맛있으시단거지

# %% [markdown]
# ***타이틀을 바꾸고싶다면?***

# %%
mooyaho.title='속시원한 농심 무야호'
mooyaho.memeshow(mooyaho.title, mooyaho.img, mooyaho.don)
# Out:
# 속시원한 농심 무야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF000820>
# 그만큼 맛있으시단거지

# %% [markdown]
# 두 번째 시도의 아쉬운 점
# - 코드는 상대적으로 깔끔하지만, 함수부분이 조금 아쉽다.
# - 코드를 수정할때마 커널재시작을 해야한다.

# %% [markdown]
# #### ***세번째 시도: 클래스***

# %% [markdown]
# 다시 밈으로 짤을 만드는 개념을 복습하면 아래와 같다.

# %% [markdown]
# (1) 무야호 원본 시청
#
# (2) 복사하고싶은 속성 추출
#
# (3) 복제가능한 어떤 틀(밈)을 만듬
#
# (4) 밈으로 부터 짤을 만든다.

# %% [markdown]
# ### ***(3) 복제가능한 틀을 만들자. = 클래스를 선언하자***

# %%
class MooYaHo(): ### MooYaHo라는 이름을 가진 클래스 선언 
    title="농심 무파마" ### 클래스안에서 정의된 변수1 
    img=Image.open('mooyaho1.jpg').resize((200,200)) ### 클래스안에서 정의된 변수2
    don="그만큼 맛있으시단거지" ### 클래스안에서 정의된 변수3
    def memeshow(self): ### 클래스안에서 정의된 함수*  
        print(self.title)
        display(self.img)
        print(self.don)

# %% [markdown]
# 모듈버전과 비교해보자.

# %% [markdown]
# ```python
# from PIL import Image
# title="농심 무파마" ### 모듈안에서 정의된 변수1
# img=Image.open('mooyaho1.jpg').resize((200,200)) ### 모듈안에서 정의된 변수2
# don="그만큼 맛있으시단거지" ### 모듈안에서 정의된 변수3
# def memeshow(title,img,don): ### 모듈안에서 정의된 함수
#     print(title)
#     display(img)
#     print(don)
# ```

# %% [markdown]
# -> 모듈버전이랑 비교하니까 함수부분이 조금 다르다.

# %% [markdown]
# 혹시 모듈처럼 아래와 같이 클래스를 선언해도 되지 않나?

# %% [markdown]
# ```python
# class MooYaHo(): ### MooYaHo라는 이름을 가진 클래스 선언
#     title="농심 무파마" ### 클래스안에서 정의된 변수1
#     img=Image.open('mooyaho1.jpg').resize((200,200)) ### 클래스안에서 정의된 변수2
#     don="그만큼 맛있으시단거지" ### 클래스안에서 정의된 변수3
#     def memeshow(title,img,don): ### 클래스안에서 정의된 함수
#         print(title)
#         display(img)
#         print(don)
# ```

# %% [markdown]
# --> 안된다... (자세한 이유는 나중에)

# %% [markdown]
# 규칙1: 클래스내에서 함수를 선언하면 반드시 첫번째 인자는 `self`를 넣어야 한다.  --> `self`가 뭘까?

# %% [markdown]
# 규칙2: 클래스 내에서 정의한 변수 (예를들면 `title`, `img`, `don`)를 사용하려면
#  - `self.title`, `self.img`, `self.don`
#  - `MooYaHo.title`, `MooYaHo.img`, `MooYaHo.don`

# %% [markdown]
# #### ***(4) 밈으로 부터 짤을 만든다. (클래스로부터 인스턴스를 생성한다.)***

# %% [markdown]
# Step1: 클래스에서 인스턴스를 만듬
#
# Step2: 인스턴스에서 memeshow라는 함수를 사용

# %% [markdown]
# ***클래스에서 인스턴스를 찍어내는 방법***
# - 함수사용법과 비슷
# - 클래스 이름을 쓰고 콘텐츠를 구체화시키는 과정에서 필요한 입력1, 입력2를 ()에 넣는다.
# - MooYaHo의 경우는 따로 입력이 없으므로, 그냥 MooYaHo하고 입력을 비워둔다. 즉 `MooYaHo()`로 생성

# %%
moo1=MooYaHo() ### 첫번째 인스턴스 생성

# %%
moo1?
# Out:
# Type:        MooYaHo
# String form: <__main__.MooYaHo object at 0x000002CDBF0122E0>
# Docstring:   <no docstring>

# %% [markdown]
# ???

# %% [markdown]
# ???? Type이 MooYaHo

# %% [markdown]
# 약간 뒷통수..

# %% [markdown]
# 원래 Type은 int, float, list 이어야 할텐데..?

# %% [markdown]
# 설마.. int 가 클래스이름이었나? --> 일단 나중에

# %% [markdown]
# 밈의 속성 확인

# %% [markdown]
# `moo1.`하고 탭을 눌러보자.

# %% [markdown]
# - 주황색: `don`, `img`, `title`
# - 파란식: `memeshow` <-- 함수
#     - 함수의 입력: self
#     - 함수의 기능: print, display, print

# %%
moo1.memeshow()
# Out:
# 농심 무파마
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 맛있으시단거지

# %% [markdown]
# ### 클래스의 위력 (이걸 다른 방법으로 어떻게 코딩해야 할지 상상해볼것)

# %% [markdown]
# ***성능1: 인스턴스에서 `.`을 찍고 접근할 수 있는 여러 자료들을 정의할 수 있다.***

# %%
moo1.title
# Out:
# '농심 무파마'

# %% [markdown]
# ***성능2:인스턴스에서 `.`을 찍고 쓸 수 있는 자체적인 함수(=method라고 함)를 정의할 수 있다.***

# %%
moo1.memeshow()
# Out:
# 농심 무파마
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 맛있으시단거지

# %% [markdown]
# ***성능3: 짤의 내용을 쉽게 바꿀 수 있다.***

# %%
moo1.title="속까지 시원해지는 농심 무야호"

# %%
moo1.memeshow()
# Out:
# 속까지 시원해지는 농심 무야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 맛있으시단거지

# %%
moo1.don="그만큼 시원하시다는 거지"
moo1.memeshow()
# Out:
# 속까지 시원해지는 농심 무야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 시원하시다는 거지

# %% [markdown]
# ***성능4: 여러짤을 동시에 쉽게 컨트롤 할 수 있다.***

# %%
moo2=MooYaHo()
moo3=MooYaHo()

# %%
moo2.title="오뚜기 진야호"
moo2.don="그만큼 진하시다는 거지~"
moo2.memeshow()
# Out:
# 오뚜기 진야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 진하시다는 거지~

# %%
moo3.title="팔도 비야호"
moo3.don="그만큼 비비고 싶으셨단 거지~"
moo3.memeshow()
# Out:
# 팔도 비야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 비비고 싶으셨단 거지~

# %%
moo2.memeshow()
# Out:
# 오뚜기 진야호
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 그만큼 진하시다는 거지~

# %% [markdown]
# ***성능 5: 틀의 재설계(밈의 재설계) $\star$$\star$$\star$***

# %% [markdown]
# 출력만 살짝 바꾸어서 MooYaHo2를 만들고 싶다.
# --> MooYaHo의 모든 내용은 그대로 가져오고, 그 살짝만 다시 조정하면 된다.

# %% [markdown]
# ```python
# #### 이런식으로 할 필요 없다.
#
# class MooYaHo2(): ### MooYaHo라는 이름을 가진 클래스 선언
#     title="농심 무파마" ### 클래스안에서 정의된 변수1
#     img=Image.open('mooyaho1.jpg').resize((200,200)) ### 클래스안에서 정의된 변수2
#     don="그만큼 맛있으시단거지" ### 클래스안에서 정의된 변수3
#     def memeshow(self): ### 클래스안에서 정의된 함수*
#         print('☆☆☆☆☆☆['+self.title+']☆☆☆☆☆☆')
#         display(self.img)
#         print('형돈:'+self.don)
# ```

# %%
class MooYaHo2(MooYaHo): 
    choi='무야~~~~~호~~~!!!'
    def memeshow(self): ### 클래스안에서 정의된 함수*  
        print('☆☆☆☆☆☆['+self.title+']☆☆☆☆☆☆')
        display(self.img)
        print(self.choi)
        print('형돈:'+self.don)

# %%
moo4=MooYaHo2()

# %%
moo4.memeshow()
# Out:
# ☆☆☆☆☆☆[농심 무파마]☆☆☆☆☆☆
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 무야~~~~~호~~~!!!
# 형돈:그만큼 맛있으시단거지

# %%
moo5=MooYaHo2()

# %%
moo5.title='오뚜기 진야호'
moo5.don='그만큼 진하시다는 거지'
moo5.memeshow()
# Out:
# ☆☆☆☆☆☆[오뚜기 진야호]☆☆☆☆☆☆
# <PIL.Image.Image image mode=RGB size=200x200 at 0x2CDBF035D60>
# 무야~~~~~호~~~!!!
# 형돈:그만큼 진하시다는 거지

# %% [markdown]
# ---

# %% [markdown]
# 숙제:
#
# (1) MooYaHo2 클래스를 인스턴스화 하여 moo6을 만들고
#
# (2) moo6의 title을 '팔도 비야호', don의 closingment를 '그만큼 비비고 싶으셨단 거지'로 바꾼뒤에
#
# (3) moo6.memeshow()를 활용하여 짤을 만들어라.

# %% [markdown]
# #### 용어정리

# %% [markdown]
# |클래스|인스턴스|
# |:-:|:-:|
# |과자틀|과자|
# |공장|공장에서 나온 생산품|
# |설계도|설계도 바탕으로 소프트웨어 세계에 구현된 실체|
# |프로그램|프로세스|

# %% [markdown]
# ### 예제2

# %%
import numpy
class Meme: # class Meme():
    n=0
    title="농심"
    def memeshow(self):
        self.n=self.n+1 
        print(self.title)
        print("*****")
        print(numpy.random.normal())
        print("*****")
        print(str(self.n)+'번째 짤')

# %%
ins1=Meme()

# %%
ins1.memeshow()
# Out:
# 농심
# *****
# 0.6393071695380305
# *****
# 2번째 짤

# %%
ins2=Meme()

# %%
ins2.title='삼양'

# %%
ins2.memeshow()
# Out:
# 삼양
# *****
# -1.5989434171003438
# *****
# 1번째 짤

# %%
ins2.n
# Out:
# 1

# %%
ins1.n
# Out:
# 1

# %% [markdown]
# ?! self에 들어가야했던것은 사실 인스턴스 이름이었음.

# %% [markdown]
# 그런데 인스턴스 이름은 모른다. (내가 뭘로 만들지 알고? )

# %% [markdown]
# 그래서 그냥 self로 하는것임.

# %% [markdown]
# #### 예제3

# %% [markdown]
# 아래코드가 아쉽다.

# %% [markdown]
# ```python
# ins2=Meme()
# ins2.title='삼양'
# ```

# %% [markdown]
# title의 디폴트가 '농심'이어야하는가?

# %% [markdown]
# 인스턴스를 만들때마다 타이틀을 새로 정하는 방식이 있으면 좋겠다.

# %% [markdown]
# `__init__` 함수 개발!!

# %% [markdown]
# ***`__init__`*** 함수란?
# - 몇 가지 사항을 빼고는 별다른 특별한 점이 없는 (어떠한 마법도 없는) 그냥 함수이다.
# - 인스턴스가 생성되는 시점에 자동으로 실행된다.
# - 특별한 첫번째 인자를 가진다. (self)
# - 클래스를 인스턴스화 할때 (...)의 값들을 함수의 입력으로 받는다.

# %%
class Meme2: # class Meme2():
    n=0
    def __init__(self,title):
        self.title=title
    def memeshow(self):
        self.n=self.n+1 
        print(self.title)
        print("*****")
        print(numpy.random.normal())
        print("*****")
        print(str(self.n)+'번째 짤')

# %%
ins3=Meme2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-06a02fb50ab1> in <module>
# ----> 1 ins3=Meme2()
#
# TypeError: __init__() missing 1 required positional argument: 'title'

# %%
ins3=Meme2('팔도')

# %%
ins3.title
# Out:
# '팔도'

# %%
ins3.memeshow()
# Out:
# 팔도
# *****
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3bcbbc2eba8c> in <module>
# ----> 1 ins3.memeshow()
#
# <ipython-input-1-d4a0d4db6b53> in memeshow(self)
#       7         print(self.title)
#       8         print("*****")
# ----> 9         print(numpy.random.normal())
#      10         print("*****")
#      11         print(str(self.n)+'번째 짤')
#
# NameError: name 'numpy' is not defined

# %% [markdown]
# 무슨일이 일어난 것일까?

# %% [markdown]
# (1) Meme2()를 인스턴스화 하는 순간에 `__init__` 이 실행되어야함.
#
# (2) 그런데 `__init__`의 첫번째 인수인 self는 입력안해도 된다고 치고, 두번째 인수인 title은 입력으로 받았어야만 하는것인데, 입력으로 받지못하여 에러메시지 발생.
#
# (3) 도데체 그럼 언제 `__init__`의 두번째 인수인 title을 넣어야할까? 곰곰히 생각해보니 Meme2를 인스턴스화 하는 순간에 입력으로 넣었어야 논리적으로 맞다. 즉 ins3=Meme2('팔도')와 같은 식으로 생성하는 순간 입력으로 넣어야 하는 것이었음.
#
# (4) `__init__`의 두번째 인자가 '팔도'로 입력되었고, 이것이 self.title 즉 ins3.title에 바로 업데이트 된 상황임.

# %% [markdown]
# ---

# %% [markdown]
# 코드의 효율적인 수정

# %%
class Meme2(Meme): # class Meme2():
    def __init__(self,title):
        self.title=title

# %%
ins3=Meme2('팔도')

# %%
ins3.memeshow()
# Out:
# 팔도
# *****
# -1.3443362132092112
# *****
# 1번째 짤

# %%
ins4=Meme2('오뚜기')

# %%
ins4.memeshow()
# Out:
# 오뚜기
# *****
# 0.2150650761559536
# *****
# 1번째 짤

# %% [markdown]
# ---

# %% [markdown]
# 욕심: 타이틀이 없다고 에러메시지를 띄우는것 보다 없으면 없는대로 만들어도 되지 않을까?

# %%
class Meme3(Meme):
    def __init__(self,title=None):
        self.title=title

# %%
ins5=Meme3()

# %%
ins5.title

# %%
ins5.memeshow()
# Out:
# None
# *****
# 0.7401309119798795
# *****
# 1번째 짤

# %%
ins5.title='야구르트'

# %%
ins5.title
# Out:
# '야구르트'

# %%
ins5.memeshow()
# Out:
# 야구르트
# *****
# -0.44833028895863924
# *****
# 2번째 짤

# %% [markdown]
# 숙제: ins5의 제목을 자신의 이름으로 바꾸고 3번째 짤을 만들어라.

# %% [markdown]
# #### [예제3] 인사관리 예제
#
# - 원시적인 형태의 클래스 $\to$ 복잡하고 다양한 속성과 기능을 가지는 클래스로 발전
# - 클래스는 무에서 점차 발전해나가는 프로토타입과 같이 코드를 설계할때 유리

# %% [markdown]
# #### Step1: 인적사항 입력

# %%
class Person:
    def __init__(self,name,job=None,pay=0):
        self.name=name
        self.job=job
        self.pay=pay

# %%
hd=Person('Hodong Kang')
iu=Person('Jieun Lee',job='dev',pay=5000)
hynn=Person('Hyewon Park',pay=3000)

# %%
print(hd.name,hd.job,hd.pay)
print(iu.name,iu.job,iu.pay)
print(hynn.name,hynn.job,hynn.pay)
# Out:
# Hodong Kang None 0
# Jieun Lee dev 5000
# Hyewon Park None 3000

# %% [markdown]
# #### Step2: 메소드 추가

# %% [markdown]
# 아이유의 연봉을 10퍼센트 올리고 싶다면?

# %%
iu.pay *= 1.1

# %%
iu.pay
# Out:
# 5500.0

# %% [markdown]
# --> 클래스의 외부에서 클래스의 속성 (`iu.pay`)을 바꾸는 동작(=함수)을 하드코딩하는 것은 좋은 방법이 아니다.

# %% [markdown]
# 좀 더 좋은 방법은 클래스 내부에 함수를 선언하는 방법이다.

# %%
class Person:
    def __init__(self,name,job=None,pay=0):
        self.name=name
        self.job=job
        self.pay=pay
    def giveRaise(self,percent): 
        self.pay *= (1+percent)

# %%
hd=Person('Hodong Kang')
iu=Person('Jieun Lee',job='dev',pay=5000)
hynn=Person('Hyewon Park',pay=3000)

# %%
print(hd.name,hd.job,hd.pay)
print(iu.name,iu.job,iu.pay)
print(hynn.name,hynn.job,hynn.pay)
# Out:
# Hodong Kang None 0
# Jieun Lee dev 5000
# Hyewon Park None 3000

# %%
iu.giveRaise(0.1)

# %%
print(iu.name,iu.job,iu.pay)
# Out:
# Jieun Lee dev 5500.0

# %%
hynn.giveRaise(0.2)
print(hynn.name,hynn.job,hynn.pay)
# Out:
# Hyewon Park None 3600.0

# %% [markdown]
# giveRaise라는 함수를 클래스 내부에 정의하면
#
# (1) 자명한 입력은 넣지 않아도 된다. (self)
#
# (2) 원래 아이유의 연봉을 올리기 위해 작성한 코드였는데, Hynn의 연봉도 올릴 수 있게 되었다.

# %% [markdown]
# note: 만약에 하드코딩을 했다면?
# ```python
# class Person:
#     def __init__(self,name,job=None,pay=0):
#         self.name=name
#         self.job=job
#         self.pay=pay
# iu=Person('Jieun Lee',job='dev',pay=5000)
# hynn=Person('Hyewon Park',pay=3000)
# iu.pay *= 1.1
# hynn.pay *= 1.2
# ```

# %% [markdown]
# note2: 함수를 클래스 외부에 선언했다면? (암묵적 전달대상 / 암묵적 업데이트 대상을 매순간 명시해야함)
# ```python
# class Person:
#     def __init__(self,name,job=None,pay=0):
#         self.name=name
#         self.job=job
#         self.pay=pay
#
# def giveRaise(pay,percent)
#     pay *= (1+percent)
#     return pay
# iu=Person('Jieun Lee',job='dev',pay=5000)
# hynn=Person('Hyewon Park',pay=3000)
# iu.pay *= giveRaise(iu.pay,0.1)
# hynn.pay *= giveRaise(hynn.pay,0.2)
# ```

# %% [markdown]
# #### Step3: 연산자 오버로딩

# %% [markdown]
# 클래스의 정보를 확인하기 위해서는?
# ```python
# print(hd.name,hd.job,hd.pay)
# print(iu.name,iu.job,iu.pay)
# print(hynn.name,hynn.job,hynn.pay)
# ```

# %% [markdown]
# 이것도 어떻게 보면 코드의 낭비 아닌가? 어차피 Person에서 보고 싶은 정보란 뻔하다.

# %% [markdown]
# 소망: 만약에 아래와 같이 타이핑만 하면 원하는 정보가 알아서 출력되면 좋겠다.
# ```python
# print(hd)
# print(iu)
# print(hynn)
# ```

# %% [markdown]
# 우리의 소망은 불가능해 보인다. `print` 함수이고 함수의 기능을 바꾸려면 함수를 다시 정의해야한다.

# %% [markdown]
# 그런데 `print`는 결국 내장함수이므로, 우리의 소망을 실현하기 위해서는 파이썬에 내장된 함수를 바꿔야한다.

# %% [markdown]
# 가능하다고 하더라도 문제이다. 그전까지 작성한 코드는 모두 어떻게 되는지?

# %%
# ?hd
# Out:
# Type:        Person
# String form: <__main__.Person object at 0x000002CDCE879CD0>
# Docstring:   <no docstring>

# %% [markdown]
# ***Type이 `Person`인 경우에 한정하여 print의 기능을 바꾼다면?***

# %% [markdown]
# `print` 내장함수는 Person타입(=내가 만든 클래스의 이름)에서만 바뀐 기능을 수행하고, 그외에서는 일반적으로 동작

# %% [markdown]
# 조금 특별한 함수 `__str__` 개발!

# %%
class Person:
    def __init__(self,name,job=None,pay=0):
        self.name=name
        self.job=job
        self.pay=pay
    def giveRaise(self,percent): 
        self.pay *= (1+percent)
    def __str__(self): 
        return str(self.name)+str(self.job)+str(self.pay)

# %% [markdown]
# ```__str__```의 특징
# - self를 입력으로 받는다.
# - 출력의 형태가 항상 문자열이어야 한다.

# %%
hd=Person('Hodong Kang')
iu=Person('Jieun Lee',job='dev',pay=5000)
hynn=Person('Hyewon Park',pay=3000)

# %%
print(hynn)
# Out:
# Hyewon ParkNone3000

# %% [markdown]
# 욕심: 보통 주피터 노트북과 같은 대화형 프롬프트에서는 print를 굳이 사용하지 않아도 원하는 출력결과를 쉽게 얻는다.

# %%
a=1
print(a)
# Out:
# 1

# %%
a=1
a
# Out:
# 1

# %% [markdown]
# 우리가 만든 클래스는?

# %%
print(hd)
# Out:
# Hodong KangNone0

# %%
hd

# %% [markdown]
# 아쉬운데?.. $\to$ `__repr__` 함수 개발

# %%
class Person:
    def __init__(self,name,job=None,pay=0):
        self.name=name
        self.job=job
        self.pay=pay
    def giveRaise(self,percent): 
        self.pay *= (1+percent)
    def __repr__(self): 
        return str(self.name)+str(self.job)+str(self.pay)

# %%
hd=Person('Hodong Kang')
iu=Person('Jieun Lee',job='dev',pay=5000)
hynn=Person('Hyewon Park',pay=3000)

# %%
hd
# Out:
# Hodong KangNone0

# %%
print(hd)
# Out:
# Hodong KangNone0

# %% [markdown]
# 보통은 `__repr__`을 더 선호한다.
# - `__repr__`이 더 많은 디스플레이 케이스에서 적용
# - 두 가지 서로 다른 형태로 디스플레이하는데 관심이 없음.

# %% [markdown]
# #### Step 4: 상속

# %% [markdown]
# print(hd)의 디스플레이 형태가 예쁘지 않음 --> 수정해보자.

# %% [markdown]
# 잔기술1

# %%
'파이는 %s' % 3.14
# Out:
# '파이는 3.14'

# %% [markdown]
# 잔기술2

# %%
'나는\n최규빈'
# Out:
# '나는\n최규빈'

# %%
print('나는\n최규빈')
# Out:
# 나는
# 최규빈

# %%
class Person2(Person):
    def __repr__(self):
        return '이름: %s \n직업: %s \n연봉: %s' % (self.name,self.job,self.pay)

# %%
hd=Person2('Hodong Kang')
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
hd
# Out:
# 이름: Hodong Kang
# 직업: None
# 연봉: 0

# %%
iu
# Out:
# 이름: Jieun Lee
# 직업: dev
# 연봉: 5000

# %%
hynn
# Out:
# 이름: Hyewon Park
# 직업: None
# 연봉: 3000

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: None
#  연봉: 0,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 5000,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3000)

# %% [markdown]
# Manager라는 클래스를 새로 만들자.

# %% [markdown]
# Person2와 동일한데, 연봉상승방법이 약간 다르다고 하자.

# %% [markdown]
# ***나쁜코드***

# %%
class Manager(Person2):
    def giveRaise(self,percent,bonus=0.1): 
        self.pay *= (1+percent+bonus)

# %%
hd=Manager('Hodong Kang', job='mgr', pay=8000)

# %%
hd
# Out:
# 이름: Hodong Kang
# 직업: mgr
# 연봉: 8000

# %%
hd.giveRaise(0.1)

# %%
hd
# Out:
# 이름: Hodong Kang
# 직업: mgr
# 연봉: 9600.000000000002

# %% [markdown]
# 연봉상승은 10%상승이지만 매니저는 기본적으로 10% 상승시키므로 총 상승분은 20%

# %% [markdown]
# ***좀 더 좋은 코드***

# %%
class Manager(Person2):
    def giveRaise(self,percent,bonus=0.1): 
        Person2.giveRaise(self,percent+bonus) 
        #클래스 상속(이전에걸 가지고 오는거)에 있는 함수를 사용하여 살짝 고치는게 더 나음

# %%
hd=Manager('Hodong Kang', job='mgr', pay=8000)

# %%
hd
# Out:
# 이름: Hodong Kang
# 직업: mgr
# 연봉: 8000

# %%
hd.giveRaise(0.1)

# %%
hd
# Out:
# 이름: Hodong Kang
# 직업: mgr
# 연봉: 9600.0

# %% [markdown]
# 만약에 우리회사의 모든 직원들의 연봉을 20%올리고 싶다면?

# %%
hd=Manager('Hodong Kang', job='mgr', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: mgr
#  연봉: 8000,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 5000,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3000)

# %%
for ins in [hd,iu,hynn]:
    ins.giveRaise(0.2)

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: mgr
#  연봉: 10400.0,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 6000.0,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3600.0)

# %% [markdown]
# ***코드분석***

# %% [markdown]
# (1) ins는 `Person2`클래스의 인스턴스 혹은 `Manager`클래스의 인스턴스

# %% [markdown]
# (2) 각 인스턴스는 각 클래스에 정의된 적당한 버전의 'giveRaise'를 활용하여 연봉이 인상된다. 즉 iu, hynn은 Person2버전의 giveRasie를 실행하고, hd는 Manager버전의 'giveRaise'를 실행

# %% [markdown]
# (3) 출력은 모두 동일한 `__repr__`을 실행

# %% [markdown]
# ***클래스가 없다면?***

# %% [markdown]
# (1) 함수의 암묵적인자를 전달하지 못하므로 코드가 길어진다. (self 인자)

# %% [markdown]
# (2) (hd, iu, hynn) 와 같이 같이 깔끔한 코드로 출력결과를 바로바로 확인하기가 불가능할 것이다. (연산자 오버로딩)

# %% [markdown]
# (3) 그 사람이 매니저인지 아닌지에 따라 연봉상승하는 방법이 다르므로, 어딘가에 if문을 넣어야 할 것이다.

# %% [markdown]
# (4) 코드의 재사용이 어렵다.. 디버깅이 어렵다.. 등등..

# %% [markdown]
# 숙제: 모든직원들의 연봉을 0.1씩 2번 상승시키는 코드를 작성하라.

# %%
class Person2(Person):
    def doubleRaise(self,percent): 
        self.pay *= (1+percent)**2
    def __repr__(self):
        return '이름: %s \n직업: %s \n연봉: %s' % (self.name,self.job,self.pay)

# %%
class Manager(Person2):
    def giveRaise(self,percent,bonus=0.1): 
        Person2.giveRaise(self,percent+bonus)
    def doubleRaise(self,percent,bonus=0.1): 
        Person2.doubleRaise(self,percent+bonus)

# %%
hd=Manager('Hodong Kang', job='mgr', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
for ins in [hd,iu,hynn]:
    ins.doubleRaise(0.1)

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: mgr
#  연봉: 11520.0,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 6050.000000000001,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3630.0000000000005)

# %% [markdown]
# ---

# %% [markdown]
# [$\ast$] `__init__`함수 재정의

# %% [markdown]
# ***생각해보니까 아래의 코드에서 호동의 직업을 매니저로 입력하는 것이 낭비같다.***

# %%
hd=Manager('Hodong Kang', job='mgr', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %% [markdown]
# 호동은 매니저클래스의 인스턴스이므로 직업은 당연히 매니저일것.

# %% [markdown]
# 굳이 `job='mgr'`와 같은 방식으로 입력하지 않아도 될것 같다.

# %% [markdown]
# 어떻게 하면 될까?

# %%
class Manager(Person2):
    def __init__(self,name,pay=0):
        self.name=name
        self.job='mgr'
        self.pay=pay
    def giveRaise(self,percent,bonus=0.1): 
        Person2.giveRaise(self,percent+bonus)

# %%
hd=Manager('Hodong Kang', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
hd
# Out:
# 이름: Hodong Kang
# 직업: mgr
# 연봉: 8000

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: mgr
#  연봉: 8000,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 5000,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3000)

# %% [markdown]
# `관찰:` 아까 매니저 클래스에서 함수를 정의하는 과정을 잘 관찰하면
# ```python
# class Manager(Person2):
#     def giveRaise(self,percent,bonus=0.1):
#         Person2.giveRaise(self,percent+bonus)
# ```
# 상속받은 클래스(서브클래스)에서 `슈퍼클래스이름.함수이름`으로 슈퍼클래스의 함수를 호출함.

# %% [markdown]
# `-` `__init__`도 함수이므로 위와 같은 방식을 사용할 수 있겠다.

# %%
class Manager(Person2):
    def __init__(self,name,pay=0):
        Person2.__init__(self,name,'mgr',pay)
    def giveRaise(self,percent,bonus=0.1): 
        Person2.giveRaise(self,percent+bonus)

# %%
hd=Manager('Hodong Kang', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: mgr
#  연봉: 8000,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 5000,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3000)

# %% [markdown]
# `-` `giveRiase`를 수정한 기법과 `__init__`을 수정한 기법은 동일함.

# %% [markdown]
# [$\ast$] 객체임베딩(객체내장)

# %% [markdown]
# `-` 클래스 Person2를 상속받지 않고 사용할 수는 없을까?

# %% [markdown]
# `-` 상속 받은 클래스를 서브클래스라고 부른다. 상위 클래스를 슈퍼클래스라고 부른다.

# %% [markdown]
# `-` 한 클래스의 어떤 함수만 호출하고 싶을때 (상속은 모든걸 가지고 오는거니까) / 여러 클래스의 원하는 함수만 가지고오는것 / 즉 끼워 넣기

# %% [markdown]
# `-` Person2를 인스턴스화 하고 그 인스턴스를 입력으로 받아 기능을 사용하는 방식을 취한다면? $\to$ 구현해보자.

# %% [markdown]
# `-` 원래코드
# ```python
# class Manager(Person2):
#     def __init__(self,name,pay=0):
#         Person2.__init__(self,name,'mgr',pay)
#     def giveRaise(self,percent,bonus=0.1):
#         Person2.giveRaise(self,percent+bonus)
# ```

# %% [markdown]
# `-` 아래와 같이 수정

# %%
class Manager():
    def __init__(self,name,pay=0):
        self.person2=Person2(name,'mgr',pay)
    def giveRaise(self,percent,bonus=0.1): 
        self.person2.giveRaise(self,percent+bonus)

# %%
hd=Manager('Hodong Kang', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
hd,iu,hynn
# Out:
# (<__main__.Manager at 0x2cdcfb1c820>,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 5000,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3000)

# %%
hd.__repr__ #상속 받지 않았으니 당연히 자동 출력이 안됨
# Out:
# <method-wrapper '__repr__' of Manager object at 0x000002CDCFB1C820>

# %%
class Manager():
    def __init__(self,name,pay=0):
        self.person2=Person2(name,'mgr',pay)
    def giveRaise(self,percent,bonus=0.1): 
        self.person2.giveRaise(self,percent+bonus)
    def __repr__(self):
        return str(self.person2)

# %%
hd=Manager('Hodong Kang', pay=8000)
iu=Person2('Jieun Lee',job='dev',pay=5000)
hynn=Person2('Hyewon Park',pay=3000)

# %%
hd,iu,hynn
# Out:
# (이름: Hodong Kang
#  직업: mgr
#  연봉: 8000,
#  이름: Jieun Lee
#  직업: dev
#  연봉: 5000,
#  이름: Hyewon Park
#  직업: None
#  연봉: 3000)

# %%
hd.person2.__repr__

# %%
hd.__repr__

# %% [markdown]
# `-` 이 예제에서는 임베딩기법이 그다지 유용하지 않다.
#
# `-` 코드에 따라서 유용할수도있다.

# %% [markdown]
# 파이썬의 모든 자료는 결국 `클래스`에서 나온 `인스턴스`이다.
#
# 따라서 결국 모든 파이썬의 자료는 객체이다.
